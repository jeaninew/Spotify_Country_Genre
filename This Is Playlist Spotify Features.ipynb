# %%
import pandas as pd 
import spotipy 
sp = spotipy.Spotify()

# %%
from spotipy.oauth2 import SpotifyClientCredentials 
cid = #your credentials
secret = #your secret key
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret) 
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) 
sp.trace=False

# %%
# All Time Low - Rock
playlist = sp.user_playlist("This Is All Time Low", "spotify:playlist:37i9dQZF1DX0RcEAGZLOBy") 
songs = playlist["tracks"]["items"] 
ids = [] 
def show_tracks(results):
    for i, item in enumerate(results['items']):
        track = item['track']
        print(
            "   %d %32.32s %s" %
            (i, track['artists'][0]['name'], track['name']))
for i in range(1): 
    results = sp.playlist(playlist['id'], fields="tracks,next")
    tracks = results['tracks']
    show_tracks(tracks)
    while tracks['next']:
        tracks = sp.next(tracks)
        show_tracks(tracks)
for i in range(0,50): 
    ids.append(songs[i]["track"]["id"])
    features = sp.audio_features(ids)
df = pd.DataFrame(features)
print(df)
# Out:
#    0                     All Time Low Backseat Serenade
#    1                     All Time Low Break Your Little Heart
#    2                     All Time Low Something's Gotta Give
#    3                     All Time Low Weightless
#    4                     All Time Low Monsters (feat. blackbear)
#    5                     All Time Low Lost In Stereo
#    6                     All Time Low Dear Maria, Count Me In
#    7                     All Time Low Damned If I Do Ya (Damned If I Don't)
#    8                     All Time Low Somewhere in Neverland
#    9                     All Time Low A Love Like War
#    10                     All Time Low Missing You
#    11                     All Time Low I Feel Like Dancin'
#    12                     All Time Low Stella
#    13                     All Time Low Time-Bomb
#    14                     All Time Low Kids In The Dark
#    15                     All Time Low Don't You Go
#    16                     All Time Low Therapy
# ...

# %%
# Drake - Rap
playlist = sp.user_playlist("This Is Drake", "spotify:playlist:37i9dQZF1DX7QOv5kjbU68") 
songs = playlist["tracks"]["items"] 
ids = [] 
def show_tracks(results):
    for i, item in enumerate(results['items']):
        track = item['track']
        print(
            "   %d %32.32s %s" %
            (i, track['artists'][0]['name'], track['name']))
for i in range(1): 
    results = sp.playlist(playlist['id'], fields="tracks,next")
    tracks = results['tracks']
    show_tracks(tracks)
    while tracks['next']:
        tracks = sp.next(tracks)
        show_tracks(tracks)
        for i in range(0,50): 
            ids.append(songs[i]["track"]["id"])
            features = sp.audio_features(ids)
            df = pd.DataFrame(features)
print(df)

# %%
# BTS - K-Pop
playlist = sp.user_playlist("This Is BTS", "spotify:playlist:4p7Lo0NQKSDm5mJeymlfHx") 
songs = playlist["tracks"]["items"] 
ids = [] 
def show_tracks(results):
    for i, item in enumerate(results['items']):
        track = item['track']
        print(
            "   %d %32.32s %s" %
            (i, track['artists'][0]['name'], track['name']))
for i in range(1): 
    results = sp.playlist(playlist['id'], fields="tracks,next")
    tracks = results['tracks']
    show_tracks(tracks)
    while tracks['next']:
        tracks = sp.next(tracks)
        show_tracks(tracks)
        for i in range(0,50): 
            ids.append(songs[i]["track"]["id"])
            features = sp.audio_features(ids)
            df = pd.DataFrame(features)
print(df)

# %%
# The Weekend - Pop
playlist = sp.user_playlist("This Is The Weekend", "spotify:playlist:37i9dQZF1DX6bnzK9KPvrz") 
songs = playlist["tracks"]["items"] 
ids = [] 
def show_tracks(results):
    for i, item in enumerate(results['items']):
        track = item['track']
        print(
            "   %d %32.32s %s" %
            (i, track['artists'][0]['name'], track['name']))
for i in range(1): 
    results = sp.playlist(playlist['id'], fields="tracks,next")
    tracks = results['tracks']
    show_tracks(tracks)
    while tracks['next']:
        tracks = sp.next(tracks)
        show_tracks(tracks)
        for i in range(0,50): 
            ids.append(songs[i]["track"]["id"])
            features = sp.audio_features(ids)
            df = pd.DataFrame(features)
print(df)

# %%
# Kacey Musgraves - Country
playlist = sp.user_playlist("This Is Kacey Musgraves", "spotify:playlist:37i9dQZF1DWWbiwkqhy6rB") 
songs = playlist["tracks"]["items"] 
ids = [] 
def show_tracks(results):
    for i, item in enumerate(results['items']):
        track = item['track']
        print(
            "   %d %32.32s %s" %
            (i, track['artists'][0]['name'], track['name']))
for i in range(1): 
    results = sp.playlist(playlist['id'], fields="tracks,next")
    tracks = results['tracks']
    show_tracks(tracks)
    while tracks['next']:
        tracks = sp.next(tracks)
        show_tracks(tracks)
        for i in range(len(songs)): 
            ids.append(songs[i]["track"]["id"])
            features = sp.audio_features(ids)
            df = pd.DataFrame(features)
print(df)

# %%
# Bad Bunny - Latin
playlist = sp.user_playlist("This Is Bad Bunny", "spotify:playlist:37i9dQZF1DX2apWzyECwyZ") 
songs = playlist["tracks"]["items"] 
ids = [] 
def show_tracks(results):
    for i, item in enumerate(results['items']):
        track = item['track']
        print(
            "   %d %32.32s %s" %
            (i, track['artists'][0]['name'], track['name']))
for i in range(1): 
    results = sp.playlist(playlist['id'], fields="tracks,next")
    tracks = results['tracks']
    show_tracks(tracks)
    while tracks['next']:
        tracks = sp.next(tracks)
        show_tracks(tracks)
        for i in range(0,50): 
            ids.append(songs[i]["track"]["id"])
            features = sp.audio_features(ids)
            df = pd.DataFrame(features)
print(df)
